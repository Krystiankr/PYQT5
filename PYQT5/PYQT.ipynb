# %%
import pandas as pd

# %%
df = pd.read_csv('sl.csv', sep=';', names=['Angielski', 'Polski', 'Frequency', 'BadlyAnswer', 'PerfectScore'])
df[['Frequency', 'BadlyAnswer', 'PerfectScore']] = 9, 0, 0
df
# Out:
#                               Angielski                         Polski  \
# 0                              gripping                     wciągający
# 1                           predictable                  przewidywalny
# 2                              touching                    wzruszający
# 3                                  weak                          słaby
# 4                               awesome                    niesamowity
# ..                                  ...                            ...
# 77                      rough and ready                  prowizoryczny
# 78                         now and then              od czasu do czasu
# 79    to be sick and tired of something            być zmęczonym czymś
# 80                        give and take  pójście na wzajemne ustępstwa
# 81  to be something through and through        być czymś w każdym calu
#
#     Frequency  BadlyAnswer  PerfectScore
# 0           9            0             0
# ...

# %%
df1= pd.read_csv('control_files/Data.csv')
df1
# Out:
#       Unnamed: 0                   Angielski                    Polski  \
# 0              0                       peers                rowiesnicy
# 1              1                    releases                   wydania
# 2              2                    nastiest                 najgorszy
# 3              3                        tend           mieć skłonności
# 4              4                   wholesale                      hurt
# ...          ...                         ...                       ...
# 2512        2512    to cost an arm and a leg          kosztować krocie
# 2513        2513    to be a pain in the neck     być nie do zniesienia
# 2514        2514         to have a big mouth            być plotkarzem
# 2515        2515    to see eye to eye on sth  być zgodnym co do czegoś
# 2516        2516  to turn a blind eye to sth  przymykać oko/zignorować
#
#       Frequency  BadlyAnswer  PerfectScore
# 0             9            0             0
# ...

# %%
df2 = pd.concat([df1, df]).reset_index().drop(['Unnamed: 0', 'index'], axis=1)
df2
# Out:
#                                 Angielski                         Polski  \
# 0                                   peers                     rowiesnicy
# 1                                releases                        wydania
# 2                                nastiest                      najgorszy
# 3                                    tend                mieć skłonności
# 4                               wholesale                           hurt
# ...                                   ...                            ...
# 2594                      rough and ready                  prowizoryczny
# 2595                         now and then              od czasu do czasu
# 2596    to be sick and tired of something            być zmęczonym czymś
# 2597                        give and take  pójście na wzajemne ustępstwa
# 2598  to be something through and through        być czymś w każdym calu
#
#       Frequency  BadlyAnswer  PerfectScore
# 0             9            0             0
# ...

# %%
df2.to_csv('control_files/Data.csv')

# %%
df2
# Out:
#                                 Angielski                         Polski  \
# 0                                   peers                     rowiesnicy
# 1                                releases                        wydania
# 2                                nastiest                      najgorszy
# 3                                    tend                mieć skłonności
# 4                               wholesale                           hurt
# ...                                   ...                            ...
# 2594                      rough and ready                  prowizoryczny
# 2595                         now and then              od czasu do czasu
# 2596    to be sick and tired of something            być zmęczonym czymś
# 2597                        give and take  pójście na wzajemne ustępstwa
# 2598  to be something through and through        być czymś w każdym calu
#
#       Frequency  BadlyAnswer  PerfectScore
# 0             9            0             0
# ...
